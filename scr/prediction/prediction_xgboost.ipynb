# %%
import os
os.chdir("../../")

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pickle
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import xgboost as xgb
from scr.util import *

# %%
df_train = pd.read_csv('data/feature_engineered/null_cat/train_scaled_for_not_gbdt.csv')
df_test = pd.read_csv('data/feature_engineered/null_cat/test_scaled_for_not_gbdt.csv')

# %%
feature = [
    'Age', 
    'DurationOfPitch', 
    'NumberOfPersonVisiting',
    'NumberOfFollowups', 
    'NumberOfTrips', 
    'MonthlyIncome', 
    #'ProdTaken',
    'Motivation', 
    'EconomicPower', 
    'TripEasier', 
    'SalesPerformance',
    'LivingCost', 
    'EconomicStability', 
    'NumberOfTrips_log', 
    'TravelCost',
    'EconomicSegment', 
    'PackageMatch', 
    'Monetary', 
    #'ContractRate_FM',
    #'ContractRate_G1',
    #'ContractRate_G2', 
    #'ContractRate_G3',
    #'ContractRate_G4',
    #'ContractRate_G5', 
    #'ContractRate_G6',
    'TypeofContact_No',
    'TypeofContact_Self Enquiry',
    'CityTier_2',
    'CityTier_3',
    'Occupation_Salaried',
    'Occupation_Small Business',
    'Gender_male', 
    'ProductPitched_Deluxe', 
    'ProductPitched_King',
    'ProductPitched_Standard',
    'ProductPitched_Super Deluxe',
    'PreferredPropertyStar_4',
    'PreferredPropertyStar_5', 
    'Passport_1',
    'PitchSatisfactionScore_2', 
    'PitchSatisfactionScore_3',
    'PitchSatisfactionScore_4',
    'PitchSatisfactionScore_5',
    'Designation_Executive',
    'Designation_Manager',
    'Designation_Senior Manager', 
    'Designation_VP',
    'Marry_Married',
    'Marry_Single', 
    'Car_No Car', 
    'Child_1_child', 
    'Child_2_child',
    'Child_3_child',
    'AgeGroup_20s',
    'AgeGroup_30s',
    'AgeGroup_40s',
    'AgeGroup_50s', 
    'AgeGroup_60s', 
    'TypeofContactNULL_1',
    'Child01_1',
    'IsFamily_1',
    'FreaqencySeg_1',
    'FreaqencySeg_2',
    'MonetarySeg_2',
    'MonetarySeg_3', 
    'MonetarySeg_4', 
    'AgeNull', 
    'DurationOfPitchNull',
    'NumberOfTripsNull', 
    'MonthlyIncomeNull'
]

X = df_train[feature]
y = df_train['ProdTaken']

# %%
models = []
scores = []

params = {
    'objective': 'binary:logistic',  # Adjust for your specific objective
    'eval_metric': 'auc',
    'learning_rate': 0.001,
    'max_depth': 6,
    'min_child_weight': 1,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'seed': 42
        }

skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
for tr_idx, va_idx in skf.split(X, y):
    tr_x, va_x = X.iloc[tr_idx], X.iloc[va_idx]
    tr_y, va_y = y.iloc[tr_idx], y.iloc[va_idx]
    
    dtrain = xgb.DMatrix(tr_x.values, label=tr_y.values)
    dvalid = xgb.DMatrix(va_x.values, label=va_y.values)
    watchlist = [(dtrain, 'train'), (dvalid, 'valid')]
    
    model = xgb.train(
        params,
        dtrain,
        num_boost_round=5000,
        evals=watchlist,
        verbose_eval=100)
    
    pred = model.predict(xgb.DMatrix(va_x.values))
    models.append(model)
    score = roc_auc_score(va_y, pred)
    scores.append(score)

print('AUC : ', scores)
# Out:
# [0]	train-auc:0.85294	valid-auc:0.77487
# [100]	train-auc:0.91371	valid-auc:0.83426
# [200]	train-auc:0.91622	valid-auc:0.83258
# [300]	train-auc:0.91885	valid-auc:0.83242
# [400]	train-auc:0.92111	valid-auc:0.83324
# [500]	train-auc:0.92368	valid-auc:0.83299
# [600]	train-auc:0.92583	valid-auc:0.83291
# [700]	train-auc:0.92807	valid-auc:0.83349
# [800]	train-auc:0.93034	valid-auc:0.83388
# [900]	train-auc:0.93217	valid-auc:0.83383
# [1000]	train-auc:0.93441	valid-auc:0.83413
# [1100]	train-auc:0.93643	valid-auc:0.83440
# [1200]	train-auc:0.93848	valid-auc:0.83480
# [1300]	train-auc:0.94055	valid-auc:0.83497
# [1400]	train-auc:0.94246	valid-auc:0.83538
# [1500]	train-auc:0.94451	valid-auc:0.83605
# [1600]	train-auc:0.94645	valid-auc:0.83654
# [1700]	train-auc:0.94836	valid-auc:0.83701
# [1800]	train-auc:0.95026	valid-auc:0.83756
# [1900]	train-auc:0.95211	valid-auc:0.83766
# [2000]	train-auc:0.95385	valid-auc:0.83834
# [2100]	train-auc:0.95555	valid-auc:0.83863
# [2200]	train-auc:0.95719	valid-auc:0.83935
# [2300]	train-auc:0.95868	valid-auc:0.83941
# [2400]	train-auc:0.96020	valid-auc:0.83980
# [2500]	train-auc:0.96174	valid-auc:0.84054
# [2600]	train-auc:0.96312	valid-auc:0.84080
# [2700]	train-auc:0.96445	valid-auc:0.84104
# [2800]	train-auc:0.96580	valid-auc:0.84112
# [2900]	train-auc:0.96719	valid-auc:0.84139
# [3000]	train-auc:0.96836	valid-auc:0.84152
# [3100]	train-auc:0.96955	valid-auc:0.84159
# [3200]	train-auc:0.97057	valid-auc:0.84177
# [3300]	train-auc:0.97161	valid-auc:0.84194
# [3400]	train-auc:0.97254	valid-auc:0.84224
# [3500]	train-auc:0.97355	valid-auc:0.84222
# [3600]	train-auc:0.97445	valid-auc:0.84206
# [3700]	train-auc:0.97540	valid-auc:0.84212
# [3800]	train-auc:0.97619	valid-auc:0.84214
# [3900]	train-auc:0.97698	valid-auc:0.84186
# [4000]	train-auc:0.97774	valid-auc:0.84186
# [4100]	train-auc:0.97854	valid-auc:0.84186
# [4200]	train-auc:0.97930	valid-auc:0.84176
# [4300]	train-auc:0.98007	valid-auc:0.84152
# [4400]	train-auc:0.98074	valid-auc:0.84177
# [4500]	train-auc:0.98147	valid-auc:0.84151
# [4600]	train-auc:0.98212	valid-auc:0.84120
# [4700]	train-auc:0.98281	valid-auc:0.84085
# [4800]	train-auc:0.98338	valid-auc:0.84067
# [4900]	train-auc:0.98401	valid-auc:0.84085
# [4999]	train-auc:0.98464	valid-auc:0.84084
# [0]	train-auc:0.84341	valid-auc:0.79343
# [100]	train-auc:0.90723	valid-auc:0.84010
# [200]	train-auc:0.91028	valid-auc:0.83831
# [300]	train-auc:0.91350	valid-auc:0.83849
# [400]	train-auc:0.91589	valid-auc:0.83918
# [500]	train-auc:0.91843	valid-auc:0.84085
# [600]	train-auc:0.92073	valid-auc:0.84094
# [700]	train-auc:0.92322	valid-auc:0.84164
# [800]	train-auc:0.92547	valid-auc:0.84125
# [900]	train-auc:0.92777	valid-auc:0.84171
# [1000]	train-auc:0.93012	valid-auc:0.84232
# [1100]	train-auc:0.93219	valid-auc:0.84263
# [1200]	train-auc:0.93454	valid-auc:0.84314
# [1300]	train-auc:0.93664	valid-auc:0.84344
# [1400]	train-auc:0.93880	valid-auc:0.84421
# [1500]	train-auc:0.94103	valid-auc:0.84477
# [1600]	train-auc:0.94297	valid-auc:0.84497
# [1700]	train-auc:0.94493	valid-auc:0.84497
# [1800]	train-auc:0.94683	valid-auc:0.84503
# [1900]	train-auc:0.94868	valid-auc:0.84508
# [2000]	train-auc:0.95064	valid-auc:0.84535
# [2100]	train-auc:0.95233	valid-auc:0.84554
# [2200]	train-auc:0.95401	valid-auc:0.84589
# [2300]	train-auc:0.95575	valid-auc:0.84587
# [2400]	train-auc:0.95738	valid-auc:0.84600
# [2500]	train-auc:0.95898	valid-auc:0.84642
# [2600]	train-auc:0.96069	valid-auc:0.84624
# [2700]	train-auc:0.96210	valid-auc:0.84635
# [2800]	train-auc:0.96358	valid-auc:0.84619
# [2900]	train-auc:0.96496	valid-auc:0.84659
# [3000]	train-auc:0.96630	valid-auc:0.84656
# [3100]	train-auc:0.96755	valid-auc:0.84706
# [3200]	train-auc:0.96868	valid-auc:0.84739
# [3300]	train-auc:0.96977	valid-auc:0.84749
# [3400]	train-auc:0.97098	valid-auc:0.84769
# [3500]	train-auc:0.97208	valid-auc:0.84751
# [3600]	train-auc:0.97306	valid-auc:0.84721
# [3700]	train-auc:0.97407	valid-auc:0.84714
# [3800]	train-auc:0.97502	valid-auc:0.84712
# [3900]	train-auc:0.97597	valid-auc:0.84691
# [4000]	train-auc:0.97693	valid-auc:0.84689
# [4100]	train-auc:0.97774	valid-auc:0.84699
# [4200]	train-auc:0.97854	valid-auc:0.84706
# [4300]	train-auc:0.97937	valid-auc:0.84692
# [4400]	train-auc:0.98009	valid-auc:0.84702
# [4500]	train-auc:0.98080	valid-auc:0.84689
# [4600]	train-auc:0.98150	valid-auc:0.84691
# [4700]	train-auc:0.98219	valid-auc:0.84686
# [4800]	train-auc:0.98284	valid-auc:0.84684
# [4900]	train-auc:0.98352	valid-auc:0.84682
# [4999]	train-auc:0.98409	valid-auc:0.84669
# [0]	train-auc:0.85635	valid-auc:0.74135
# [100]	train-auc:0.91051	valid-auc:0.81009
# [200]	train-auc:0.91289	valid-auc:0.80963
# [300]	train-auc:0.91621	valid-auc:0.80935
# [400]	train-auc:0.91792	valid-auc:0.80820
# [500]	train-auc:0.91998	valid-auc:0.80827
# [600]	train-auc:0.92256	valid-auc:0.80763
# [700]	train-auc:0.92501	valid-auc:0.80798
# [800]	train-auc:0.92721	valid-auc:0.80752
# [900]	train-auc:0.92919	valid-auc:0.80734
# [1000]	train-auc:0.93133	valid-auc:0.80731
# [1100]	train-auc:0.93338	valid-auc:0.80677
# [1200]	train-auc:0.93535	valid-auc:0.80623
# [1300]	train-auc:0.93751	valid-auc:0.80569
# [1400]	train-auc:0.93970	valid-auc:0.80580
# [1500]	train-auc:0.94210	valid-auc:0.80550
# [1600]	train-auc:0.94433	valid-auc:0.80584
# [1700]	train-auc:0.94659	valid-auc:0.80575
# [1800]	train-auc:0.94861	valid-auc:0.80634
# [1900]	train-auc:0.95073	valid-auc:0.80658
# [2000]	train-auc:0.95258	valid-auc:0.80690
# [2100]	train-auc:0.95447	valid-auc:0.80688
# [2200]	train-auc:0.95620	valid-auc:0.80715
# [2300]	train-auc:0.95805	valid-auc:0.80784
# [2400]	train-auc:0.95975	valid-auc:0.80822
# [2500]	train-auc:0.96147	valid-auc:0.80833
# [2600]	train-auc:0.96296	valid-auc:0.80876
# [2700]	train-auc:0.96443	valid-auc:0.80860
# [2800]	train-auc:0.96581	valid-auc:0.80877
# [2900]	train-auc:0.96713	valid-auc:0.80908
# [3000]	train-auc:0.96841	valid-auc:0.80896
# [3100]	train-auc:0.96976	valid-auc:0.80931
# [3200]	train-auc:0.97092	valid-auc:0.80916
# [3300]	train-auc:0.97207	valid-auc:0.80918
# [3400]	train-auc:0.97303	valid-auc:0.80931
# [3500]	train-auc:0.97417	valid-auc:0.80908
# [3600]	train-auc:0.97500	valid-auc:0.80950
# [3700]	train-auc:0.97588	valid-auc:0.80955
# [3800]	train-auc:0.97679	valid-auc:0.80963
# [3900]	train-auc:0.97770	valid-auc:0.80983
# [4000]	train-auc:0.97847	valid-auc:0.80926
# [4100]	train-auc:0.97922	valid-auc:0.80896
# [4200]	train-auc:0.97991	valid-auc:0.80909
# [4300]	train-auc:0.98061	valid-auc:0.80904
# [4400]	train-auc:0.98137	valid-auc:0.80869
# [4500]	train-auc:0.98209	valid-auc:0.80889
# [4600]	train-auc:0.98270	valid-auc:0.80865
# [4700]	train-auc:0.98330	valid-auc:0.80877
# [4800]	train-auc:0.98398	valid-auc:0.80864
# [4900]	train-auc:0.98459	valid-auc:0.80859
# [4999]	train-auc:0.98516	valid-auc:0.80867
# [0]	train-auc:0.83675	valid-auc:0.75215
# [100]	train-auc:0.90856	valid-auc:0.82560
# [200]	train-auc:0.90996	valid-auc:0.82587
# [300]	train-auc:0.91353	valid-auc:0.82569
# [400]	train-auc:0.91667	valid-auc:0.82589
# [500]	train-auc:0.92020	valid-auc:0.82564
# [600]	train-auc:0.92299	valid-auc:0.82537
# [700]	train-auc:0.92592	valid-auc:0.82560
# [800]	train-auc:0.92866	valid-auc:0.82467
# [900]	train-auc:0.93094	valid-auc:0.82488
# [1000]	train-auc:0.93334	valid-auc:0.82478
# [1100]	train-auc:0.93562	valid-auc:0.82471
# [1200]	train-auc:0.93814	valid-auc:0.82454
# [1300]	train-auc:0.94055	valid-auc:0.82420
# [1400]	train-auc:0.94289	valid-auc:0.82402
# [1500]	train-auc:0.94511	valid-auc:0.82388
# [1600]	train-auc:0.94724	valid-auc:0.82312
# [1700]	train-auc:0.94940	valid-auc:0.82290
# [1800]	train-auc:0.95139	valid-auc:0.82240
# [1900]	train-auc:0.95342	valid-auc:0.82221
# [2000]	train-auc:0.95526	valid-auc:0.82204
# [2100]	train-auc:0.95697	valid-auc:0.82176
# [2200]	train-auc:0.95840	valid-auc:0.82182
# [2300]	train-auc:0.96006	valid-auc:0.82193
# [2400]	train-auc:0.96158	valid-auc:0.82187
# [2500]	train-auc:0.96300	valid-auc:0.82231
# [2600]	train-auc:0.96451	valid-auc:0.82255
# [2700]	train-auc:0.96586	valid-auc:0.82284
# [2800]	train-auc:0.96712	valid-auc:0.82275
# [2900]	train-auc:0.96851	valid-auc:0.82275
# [3000]	train-auc:0.96961	valid-auc:0.82241
# [3100]	train-auc:0.97076	valid-auc:0.82241
# [3200]	train-auc:0.97187	valid-auc:0.82218
# [3300]	train-auc:0.97290	valid-auc:0.82194
# [3400]	train-auc:0.97391	valid-auc:0.82176
# [3500]	train-auc:0.97483	valid-auc:0.82189
# [3600]	train-auc:0.97568	valid-auc:0.82194
# [3700]	train-auc:0.97663	valid-auc:0.82176
# [3800]	train-auc:0.97739	valid-auc:0.82176
# [3900]	train-auc:0.97820	valid-auc:0.82159
# [4000]	train-auc:0.97902	valid-auc:0.82140
# [4100]	train-auc:0.97974	valid-auc:0.82128
# [4200]	train-auc:0.98055	valid-auc:0.82118
# [4300]	train-auc:0.98126	valid-auc:0.82113
# [4400]	train-auc:0.98197	valid-auc:0.82081
# [4500]	train-auc:0.98269	valid-auc:0.82075
# [4600]	train-auc:0.98334	valid-auc:0.82061
# [4700]	train-auc:0.98393	valid-auc:0.82054
# [4800]	train-auc:0.98449	valid-auc:0.82042
# [4900]	train-auc:0.98506	valid-auc:0.82024
# [4999]	train-auc:0.98565	valid-auc:0.81999
# [0]	train-auc:0.86364	valid-auc:0.76337
# [100]	train-auc:0.91069	valid-auc:0.80087
# [200]	train-auc:0.91401	valid-auc:0.79956
# [300]	train-auc:0.91819	valid-auc:0.79962
# [400]	train-auc:0.92076	valid-auc:0.79817
# [500]	train-auc:0.92336	valid-auc:0.79724
# [600]	train-auc:0.92626	valid-auc:0.79697
# [700]	train-auc:0.92908	valid-auc:0.79678
# [800]	train-auc:0.93182	valid-auc:0.79673
# [900]	train-auc:0.93426	valid-auc:0.79624
# [1000]	train-auc:0.93683	valid-auc:0.79609
# [1100]	train-auc:0.93942	valid-auc:0.79536
# [1200]	train-auc:0.94209	valid-auc:0.79513
# [1300]	train-auc:0.94438	valid-auc:0.79472
# [1400]	train-auc:0.94664	valid-auc:0.79465
# [1500]	train-auc:0.94928	valid-auc:0.79374
# [1600]	train-auc:0.95137	valid-auc:0.79374
# [1700]	train-auc:0.95345	valid-auc:0.79332
# [1800]	train-auc:0.95539	valid-auc:0.79298
# [1900]	train-auc:0.95725	valid-auc:0.79340
# [2000]	train-auc:0.95906	valid-auc:0.79308
# [2100]	train-auc:0.96072	valid-auc:0.79322
# [2200]	train-auc:0.96256	valid-auc:0.79362
# [2300]	train-auc:0.96409	valid-auc:0.79364
# [2400]	train-auc:0.96550	valid-auc:0.79413
# [2500]	train-auc:0.96697	valid-auc:0.79447
# [2600]	train-auc:0.96842	valid-auc:0.79472
# [2700]	train-auc:0.96996	valid-auc:0.79513
# [2800]	train-auc:0.97120	valid-auc:0.79518
# [2900]	train-auc:0.97243	valid-auc:0.79550
# [3000]	train-auc:0.97346	valid-auc:0.79577
# [3100]	train-auc:0.97464	valid-auc:0.79575
# [3200]	train-auc:0.97570	valid-auc:0.79619
# [3300]	train-auc:0.97668	valid-auc:0.79641
# [3400]	train-auc:0.97757	valid-auc:0.79629
# [3500]	train-auc:0.97850	valid-auc:0.79659
# [3600]	train-auc:0.97934	valid-auc:0.79705
# [3700]	train-auc:0.98017	valid-auc:0.79702
# [3800]	train-auc:0.98101	valid-auc:0.79686
# [3900]	train-auc:0.98179	valid-auc:0.79695
# [4000]	train-auc:0.98254	valid-auc:0.79668
# [4100]	train-auc:0.98330	valid-auc:0.79665
# [4200]	train-auc:0.98399	valid-auc:0.79658
# [4300]	train-auc:0.98457	valid-auc:0.79639
# [4400]	train-auc:0.98526	valid-auc:0.79595
# [4500]	train-auc:0.98586	valid-auc:0.79595
# [4600]	train-auc:0.98644	valid-auc:0.79577
# [4700]	train-auc:0.98703	valid-auc:0.79610
# [4800]	train-auc:0.98757	valid-auc:0.79617
# [4900]	train-auc:0.98811	valid-auc:0.79604
# [4999]	train-auc:0.98855	valid-auc:0.79575
# AUC :  [0.8408361204013378, 0.8466889632107024, 0.8086710173521526, 0.8199861722399284, 0.7957501435762305]
